# %% [markdown]
# # Scrapping

# %%
pip install requests googlesearch-python
# Out:
# Requirement already satisfied: requests in d:\python\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in d:\python\lib\site-packages (4.11.1)
# Collecting googlesearch-python
#   Downloading googlesearch_python-1.2.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\python\lib\site-packages (from requests) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\python\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\python\lib\site-packages (from requests) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in d:\python\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in d:\python\lib\site-packages (from beautifulsoup4) (2.3.2.post1)
# Downloading googlesearch_python-1.2.5-py3-none-any.whl (4.8 kB)
# Installing collected packages: googlesearch-python
# Successfully installed googlesearch-python-1.2.5
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (d:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\python\lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: D:\Python\python.exe -m pip install --upgrade pip

# %%
import os
import time
import random
from googlesearch import search
import requests
from PyPDF2 import PdfReader
from PyPDF2.errors import PdfReadError

# Directory to save the PDFs
base_save_directory = "../data"
if not os.path.exists(base_save_directory):
    os.makedirs(base_save_directory)

# List of queries to collect only SQL course and textbook PDFs explaining SQL concepts
queries = [
    "filetype:pdf Cours SQL lang:fr",
    "filetype:pdf Livre SQL lang:fr",
    "filetype:pdf Concepts de bases de données SQL lang:fr",
    "filetype:pdf Apprendre les concepts SQL lang:fr",
    "filetype:pdf Cours SQL concepts avancés lang:fr",
    "filetype:pdf Cours bases de données relationnelles SQL lang:fr",
    "filetype:pdf Introduction aux concepts SQL lang:fr",
    "filetype:pdf Livre sur les bases de données SQL lang:fr",
    "filetype:pdf Comprendre SQL concepts lang:fr",
    "filetype:pdf Cours SQL pour débutants lang:fr",
    "filetype:pdf Concepts SQL pour les bases de données lang:fr",
    "filetype:pdf Apprendre les jointures SQL lang:fr",
    "filetype:pdf Livre sur SQL et bases de données lang:fr",
    "filetype:pdf Cours SQL sous-requêtes lang:fr",
    "filetype:pdf Concepts avancés des bases de données SQL lang:fr"
]

# Directory to save the PDFs
if not os.path.exists(base_save_directory):
    os.makedirs(base_save_directory)

# Function to download a PDF file from a URL
def download_pdf(pdf_url, save_directory):
    try:
        response = requests.get(pdf_url, stream=True)
        response.raise_for_status()
        pdf_name = pdf_url.split("/")[-1]
        file_path = os.path.join(save_directory, pdf_name)

        # Check for duplicates
        if os.path.exists(file_path):
            print(f"{pdf_name} already exists. Skipping download.")
            return file_path, False

        with open(file_path, "wb") as pdf_file:
            for chunk in response.iter_content(chunk_size=1024):
                if chunk:
                    pdf_file.write(chunk)
        print(f"Downloaded: {pdf_name}")
        return file_path, True
    except Exception as e:
        print(f"Failed to download {pdf_url}: {e}")
        return None, False

# Function to extract PDF links from a Google search result page
def extract_pdf_links(query):
    pdf_links = []
    try:
        for url in search(query, num_results=100, lang="fr"):
            if url.endswith(".pdf"):
                pdf_links.append(url)
    except Exception as e:
        print(f"Error extracting PDFs for query {query}: {e}")
    return pdf_links

# Function to filter PDFs based on relevance to SQL courses (exclude tutorials, guides, etc.)
def filter_pdf_links(pdf_links):
    filtered_links = []
    for link in pdf_links:
        if 'cours' in link or 'livre' in link or 'concepts' in link:
            filtered_links.append(link)
    return filtered_links

# Function to check if a PDF is corrupted
def is_pdf_corrupted(pdf_path):
    try:
        with open(pdf_path, "rb") as file:
            reader = PdfReader(file)
            # Try to read the first page
            reader.pages[0]
        return False  # If no error occurs, the PDF is valid
    except PdfReadError as e:
        print(f"Corrupted PDF detected: {pdf_path}, Error: {e}")
        return True
    except Exception as e:
        print(f"Error reading PDF {pdf_path}: {e}")
        return True

# Main function to collect SQL PDFs and organize them
def collect_sql_pdfs():
    print(f"\n*****************Searching for SQL PDFs...******************")
    for query in queries:
        print(f"Searching for: {query}")
        pdf_links = extract_pdf_links(query)
        print(f"Found {len(pdf_links)} PDFs for query: {query}")

        filtered_links = filter_pdf_links(pdf_links)
        print(f"Filtered to {len(filtered_links)} relevant PDFs for query: {query}")

        for pdf_url in filtered_links:
            file_path, downloaded = download_pdf(pdf_url, base_save_directory)
            if downloaded and file_path:
                if is_pdf_corrupted(file_path):  # Check if the file is corrupted
                    print(f"Deleting corrupted PDF: {file_path}")
                    os.remove(file_path)  # Remove the corrupted PDF
            time.sleep(random.uniform(1, 3))  # Random sleep to avoid overwhelming servers

if __name__ == "__main__":
    collect_sql_pdfs()
# Out:
# *****************Searching for SQL PDFs...******************
# Searching for: filetype:pdf Cours SQL lang:fr
# Found 92 PDFs for query: filetype:pdf Cours SQL lang:fr
# Filtered to 29 relevant PDFs for query: filetype:pdf Cours SQL lang:fr
# Downloaded: cours-sql-sh-.pdf
# Downloaded: slides-michel-slides.pdf
# Downloaded: c2.pdf
# Downloaded: hasssclic521.pdf
# Downloaded: sgbd-b7.pdf
# Downloaded: 3i009cours1rappels2017.pdf
# Failed to download https://perso.liris.cnrs.fr/veronique.deslandres/lib/exe/fetch.php%3Fmedia%3Dstart:ens:java:cours6.1-jdbc-2021.pdf: [Errno 22] Invalid argument: '../data\\fetch.php%3Fmedia%3Dstart:ens:java:cours6.1-jdbc-2021.pdf'
# Downloaded: JDBC.pdf
# Downloaded: coursphp3.pdf
# Failed to download https://lig-membres.imag.fr/genoud/teaching/PL2AI/cours/pdf/PL2/PL2_16JDBC.pdf: 404 Client Error: Not Found for url: https://lig-membres.imag.fr/genoud/teaching/PL2AI/cours/pdf/PL2/PL2_16JDBC.pdf/
# Downloaded: cours.pdf
# Downloaded: cours8.pdf
# Downloaded: Cours-JPA-v1.3.pdf
# Downloaded: NFP214_020_Presentation_du_langage_JAVA.pdf
# Downloaded: 0514-pdf-support-de-cours-introduction-a-sql-et-mysql.pdf
# Downloaded: cours11.pdf
# Downloaded: Programmation_PHP_Sessions_Mysql.pdf
# Downloaded: NFI5_TextVersion_FR.pdf
# Downloaded: php4.pdf
# Downloaded: php-support.pdf
# Corrupted PDF detected: ../data\php-support.pdf, Error: EOF marker not found
# Deleting corrupted PDF: ../data\php-support.pdf
# Downloaded: cours-php.pdf
# Downloaded: php-mysql.pdf
# Downloaded: livre_typo3.pdf
# Downloaded: 5xbak.pdf
# Downloaded: livret_master_tilt_2022-2023_final.pdf
# Failed to download https://lig-membres.imag.fr/genoud/teaching/PL2AI/cours/pdf/PL2/PL2_07Packages.pdf: 404 Client Error: Not Found for url: https://lig-membres.imag.fr/genoud/teaching/PL2AI/cours/pdf/PL2/PL2_07Packages.pdf/
# Downloaded: sujet.pdf
# Downloaded: jdbc_6pp.pdf
# Downloaded: I-%20Le%20langage%20Java.pdf
# Searching for: filetype:pdf Livre SQL lang:fr
# Found 92 PDFs for query: filetype:pdf Livre SQL lang:fr
# Filtered to 19 relevant PDFs for query: filetype:pdf Livre SQL lang:fr
# cours-sql-sh-.pdf already exists. Skipping download.
# c2.pdf already exists. Skipping download.
# Downloaded: livre-micro-application-php-mysql-et-css-fr.pdf
# hasssclic521.pdf already exists. Skipping download.
# Downloaded: table-des-matieres.pdf
# Failed to download https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf: 403 Client Error: Forbidden for url: https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf
# cours.pdf already exists. Skipping download.
# Downloaded: sgbd2_part4.pdf
# cours11.pdf already exists. Skipping download.
# Downloaded: livreArchiWeb-2016.pdf
# Downloaded: F006116.pdf
# Downloaded: book.pdf
# Downloaded: SA_coursIV.pdf
# Downloaded: php-support.pdf
# Corrupted PDF detected: ../data\php-support.pdf, Error: EOF marker not found
# Deleting corrupted PDF: ../data\php-support.pdf
# livret_master_tilt_2022-2023_final.pdf already exists. Skipping download.
# Downloaded: xml.pdf
# I-%20Le%20langage%20Java.pdf already exists. Skipping download.
# Downloaded: cours4-Xquery.pdf
# Downloaded: courstat-5-8.pdf
# Searching for: filetype:pdf Concepts de bases de données SQL lang:fr
# Found 92 PDFs for query: filetype:pdf Concepts de bases de données SQL lang:fr
# Filtered to 18 relevant PDFs for query: filetype:pdf Concepts de bases de données SQL lang:fr
# cours-sql-sh-.pdf already exists. Skipping download.
# slides-michel-slides.pdf already exists. Skipping download.
# Downloaded: 20XX-XX.cours.01-introduction.bdd.pdf
# Downloaded: hassclic667.pdf
# Failed to download https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf: 403 Client Error: Forbidden for url: https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf
# Downloaded: 3i009cours1rappel2016.pdf
# Downloaded: DSS_MAN.pdf
# JDBC.pdf already exists. Skipping download.
# Failed to download https://perso.liris.cnrs.fr/veronique.deslandres/lib/exe/fetch.php%3Fmedia%3Dstart:ens:java:cours6.1-jdbc-2021.pdf: [Errno 22] Invalid argument: '../data\\fetch.php%3Fmedia%3Dstart:ens:java:cours6.1-jdbc-2021.pdf'
# NFI5_TextVersion_FR.pdf already exists. Skipping download.
# courstat-5-8.pdf already exists. Skipping download.
# sgbd2_part4.pdf already exists. Skipping download.
# Downloaded: DVWA_crack.pdf
# Cours-JPA-v1.3.pdf already exists. Skipping download.
# livreArchiWeb-2016.pdf already exists. Skipping download.
# Downloaded: back-end-4.pdf
# cours.pdf already exists. Skipping download.
# 20XX-XX.cours.01-introduction.bdd.pdf already exists. Skipping download.
# Searching for: filetype:pdf Apprendre les concepts SQL lang:fr
# Found 0 PDFs for query: filetype:pdf Apprendre les concepts SQL lang:fr
# Filtered to 0 relevant PDFs for query: filetype:pdf Apprendre les concepts SQL lang:fr
# Searching for: filetype:pdf Cours SQL concepts avancés lang:fr
# Found 90 PDFs for query: filetype:pdf Cours SQL concepts avancés lang:fr
# Filtered to 17 relevant PDFs for query: filetype:pdf Cours SQL concepts avancés lang:fr
# cours-sql-sh-.pdf already exists. Skipping download.
# Failed to download https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf: 403 Client Error: Forbidden for url: https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf
# sgbd-b7.pdf already exists. Skipping download.
# Failed to download https://perso.liris.cnrs.fr/veronique.deslandres/lib/exe/fetch.php%3Fmedia%3Dstart:ens:java:cours6.1-jdbc-2021.pdf: [Errno 22] Invalid argument: '../data\\fetch.php%3Fmedia%3Dstart:ens:java:cours6.1-jdbc-2021.pdf'
# Downloaded: leilclic708.pdf
# DSS_MAN.pdf already exists. Skipping download.
# hassclic667.pdf already exists. Skipping download.
# NFI5_TextVersion_FR.pdf already exists. Skipping download.
# back-end-4.pdf already exists. Skipping download.
# Downloaded: coursTechWebJ2EE2009-2013-p.pdf
# Downloaded: JavaL3Mourlin.pdf
# Downloaded: repcours_2008-2009_CyclesSup.pdf
# livreArchiWeb-2016.pdf already exists. Skipping download.
# Downloaded: 1e-NSI-prog2019.pdf
# Downloaded: Java2EaM.pdf
# F006116.pdf already exists. Skipping download.
# Downloaded: NFI7_TextVersion_FR.pdf
# Searching for: filetype:pdf Cours bases de données relationnelles SQL lang:fr
# Found 93 PDFs for query: filetype:pdf Cours bases de données relationnelles SQL lang:fr
# Filtered to 20 relevant PDFs for query: filetype:pdf Cours bases de données relationnelles SQL lang:fr
# slides-michel-slides.pdf already exists. Skipping download.
# cours-sql-sh-.pdf already exists. Skipping download.
# leilclic708.pdf already exists. Skipping download.
# sgbd-b7.pdf already exists. Skipping download.
# 20XX-XX.cours.01-introduction.bdd.pdf already exists. Skipping download.
# Failed to download https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf: 403 Client Error: Forbidden for url: https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf
# hassclic667.pdf already exists. Skipping download.
# JDBC.pdf already exists. Skipping download.
# coursphp3.pdf already exists. Skipping download.
# 5xbak.pdf already exists. Skipping download.
# Cours-JPA-v1.3.pdf already exists. Skipping download.
# NFI5_TextVersion_FR.pdf already exists. Skipping download.
# courstat-5-8.pdf already exists. Skipping download.
# DSS_MAN.pdf already exists. Skipping download.
# livret_master_tilt_2022-2023_final.pdf already exists. Skipping download.
# livreArchiWeb-2016.pdf already exists. Skipping download.
# back-end-4.pdf already exists. Skipping download.
# Downloaded: coursXML.pdf
# Downloaded: combined.pdf
# F006116.pdf already exists. Skipping download.
# Searching for: filetype:pdf Introduction aux concepts SQL lang:fr
# Found 90 PDFs for query: filetype:pdf Introduction aux concepts SQL lang:fr
# Filtered to 17 relevant PDFs for query: filetype:pdf Introduction aux concepts SQL lang:fr
# cours-sql-sh-.pdf already exists. Skipping download.
# slides-michel-slides.pdf already exists. Skipping download.
# 20XX-XX.cours.01-introduction.bdd.pdf already exists. Skipping download.
# sgbd-b7.pdf already exists. Skipping download.
# 3i009cours1rappels2017.pdf already exists. Skipping download.
# Failed to download https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf: 403 Client Error: Forbidden for url: https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf
# Downloaded: patterns_intro_cours01.pdf
# Cours-JPA-v1.3.pdf already exists. Skipping download.
# sgbd2_part4.pdf already exists. Skipping download.
# NFI5_TextVersion_FR.pdf already exists. Skipping download.
# Downloaded: course-catalogue-paris-fall-2024.pdf
# livreArchiWeb-2016.pdf already exists. Skipping download.
# Downloaded: IntroJava_6pp.pdf
# Downloaded: course-catalogue-for-exchange-students-paris-fall-2024-v3_0.pdf
# Downloaded: SL-275.pdf
# combined.pdf already exists. Skipping download.
# repcours_2008-2009_CyclesSup.pdf already exists. Skipping download.
# Searching for: filetype:pdf Livre sur les bases de données SQL lang:fr
# Found 91 PDFs for query: filetype:pdf Livre sur les bases de données SQL lang:fr
# Filtered to 14 relevant PDFs for query: filetype:pdf Livre sur les bases de données SQL lang:fr
# cours-sql-sh-.pdf already exists. Skipping download.
# c2.pdf already exists. Skipping download.
# Failed to download https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf: 403 Client Error: Forbidden for url: https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf
# Downloaded: leilclic697.pdf
# hasssclic521.pdf already exists. Skipping download.
# DSS_MAN.pdf already exists. Skipping download.
# livre-micro-application-php-mysql-et-css-fr.pdf already exists. Skipping download.
# table-des-matieres.pdf already exists. Skipping download.
# courstat-5-8.pdf already exists. Skipping download.
# F006116.pdf already exists. Skipping download.
# livreArchiWeb-2016.pdf already exists. Skipping download.
# back-end-4.pdf already exists. Skipping download.
# Downloaded: php-support.pdf
# Corrupted PDF detected: ../data\php-support.pdf, Error: EOF marker not found
# Deleting corrupted PDF: ../data\php-support.pdf
# book.pdf already exists. Skipping download.
# Searching for: filetype:pdf Comprendre SQL concepts lang:fr
# Found 89 PDFs for query: filetype:pdf Comprendre SQL concepts lang:fr
# Filtered to 18 relevant PDFs for query: filetype:pdf Comprendre SQL concepts lang:fr
# cours-sql-sh-.pdf already exists. Skipping download.
# slides-michel-slides.pdf already exists. Skipping download.
# 20XX-XX.cours.01-introduction.bdd.pdf already exists. Skipping download.
# sgbd-b7.pdf already exists. Skipping download.
# Failed to download https://perso.liris.cnrs.fr/veronique.deslandres/lib/exe/fetch.php%3Fmedia%3Dstart:ens:java:cours6.1-jdbc-2021.pdf: [Errno 22] Invalid argument: '../data\\fetch.php%3Fmedia%3Dstart:ens:java:cours6.1-jdbc-2021.pdf'
# Failed to download https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf: 403 Client Error: Forbidden for url: https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf
# 3i009cours1rappels2017.pdf already exists. Skipping download.
# sgbd2_part4.pdf already exists. Skipping download.
# cours.pdf already exists. Skipping download.
# courstat-5-8.pdf already exists. Skipping download.
# NFI5_TextVersion_FR.pdf already exists. Skipping download.
# JDBC.pdf already exists. Skipping download.
# SL-275.pdf already exists. Skipping download.
# DSS_MAN.pdf already exists. Skipping download.
# IntroJava_6pp.pdf already exists. Skipping download.
# livreArchiWeb-2016.pdf already exists. Skipping download.
# Failed to download https://librecours.net/modules/dev/js02/solpdf?contentName=js02.pdf: [Errno 22] Invalid argument: '../data\\solpdf?contentName=js02.pdf'
# Downloaded: 1-concept.pdf
# Searching for: filetype:pdf Cours SQL pour débutants lang:fr
# Found 95 PDFs for query: filetype:pdf Cours SQL pour débutants lang:fr
# Filtered to 22 relevant PDFs for query: filetype:pdf Cours SQL pour débutants lang:fr
# cours-sql-sh-.pdf already exists. Skipping download.
# c2.pdf already exists. Skipping download.
# DSS_MAN.pdf already exists. Skipping download.
# cours.pdf already exists. Skipping download.
# Downloaded: coursMysql.pdf
# 3i009cours1rappel2016.pdf already exists. Skipping download.
# sgbd2_part4.pdf already exists. Skipping download.
# Downloaded: leilclic869.pdf
# 5xbak.pdf already exists. Skipping download.
# NFI5_TextVersion_FR.pdf already exists. Skipping download.
# Downloaded: php-support.pdf
# Corrupted PDF detected: ../data\php-support.pdf, Error: EOF marker not found
# Deleting corrupted PDF: ../data\php-support.pdf
# SL-275.pdf already exists. Skipping download.
# coursTechWebJ2EE2009-2013-p.pdf already exists. Skipping download.
# F006116.pdf already exists. Skipping download.
# 1e-NSI-prog2019.pdf already exists. Skipping download.
# livreArchiWeb-2016.pdf already exists. Skipping download.
# 3i009cours1rappels2017.pdf already exists. Skipping download.
# livret_master_tilt_2022-2023_final.pdf already exists. Skipping download.
# php4.pdf already exists. Skipping download.
# cours-php.pdf already exists. Skipping download.
# combined.pdf already exists. Skipping download.
# xml.pdf already exists. Skipping download.
# Searching for: filetype:pdf Concepts SQL pour les bases de données lang:fr
# Found 90 PDFs for query: filetype:pdf Concepts SQL pour les bases de données lang:fr
# Filtered to 17 relevant PDFs for query: filetype:pdf Concepts SQL pour les bases de données lang:fr
# cours-sql-sh-.pdf already exists. Skipping download.
# slides-michel-slides.pdf already exists. Skipping download.
# 20XX-XX.cours.01-introduction.bdd.pdf already exists. Skipping download.
# Failed to download https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf: 403 Client Error: Forbidden for url: https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf
# leilclic708.pdf already exists. Skipping download.
# sgbd-b7.pdf already exists. Skipping download.
# 3i009cours1rappels2017.pdf already exists. Skipping download.
# hassclic667.pdf already exists. Skipping download.
# Failed to download https://perso.liris.cnrs.fr/veronique.deslandres/lib/exe/fetch.php%3Fmedia%3Dstart:ens:java:cours6.1-jdbc-2021.pdf: [Errno 22] Invalid argument: '../data\\fetch.php%3Fmedia%3Dstart:ens:java:cours6.1-jdbc-2021.pdf'
# DSS_MAN.pdf already exists. Skipping download.
# sgbd2_part4.pdf already exists. Skipping download.
# courstat-5-8.pdf already exists. Skipping download.
# NFI5_TextVersion_FR.pdf already exists. Skipping download.
# JDBC.pdf already exists. Skipping download.
# Cours-JPA-v1.3.pdf already exists. Skipping download.
# back-end-4.pdf already exists. Skipping download.
# livreArchiWeb-2016.pdf already exists. Skipping download.
# Searching for: filetype:pdf Apprendre les jointures SQL lang:fr
# Found 93 PDFs for query: filetype:pdf Apprendre les jointures SQL lang:fr
# Filtered to 10 relevant PDFs for query: filetype:pdf Apprendre les jointures SQL lang:fr
# cours-sql-sh-.pdf already exists. Skipping download.
# slides-michel-slides.pdf already exists. Skipping download.
# hasssclic521.pdf already exists. Skipping download.
# DSS_MAN.pdf already exists. Skipping download.
# leilclic708.pdf already exists. Skipping download.
# Failed to download https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf: 403 Client Error: Forbidden for url: https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf
# 5xbak.pdf already exists. Skipping download.
# Downloaded: F006003.pdf
# Downloaded: PHP%20%20MySQL%20et%20CSS.pdf
# Downloaded: Linux-%20maitrisez%20l-administration%20du%20syst-me_par_Trauma.pdf
# Searching for: filetype:pdf Livre sur SQL et bases de données lang:fr
# Found 90 PDFs for query: filetype:pdf Livre sur SQL et bases de données lang:fr
# Filtered to 14 relevant PDFs for query: filetype:pdf Livre sur SQL et bases de données lang:fr
# cours-sql-sh-.pdf already exists. Skipping download.
# Failed to download https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf: 403 Client Error: Forbidden for url: https://www.researchgate.net/profile/Nassim_Dennouni/publication/324504264_Support_de_cours_Base_de_donnees_avancees/links/5ad0c7fe0f7e9b285930e0ba/Support-de-cours-Base-de-donnees-avancees.pdf
# hasssclic521.pdf already exists. Skipping download.
# DSS_MAN.pdf already exists. Skipping download.
# livre-micro-application-php-mysql-et-css-fr.pdf already exists. Skipping download.
# leilclic697.pdf already exists. Skipping download.
# courstat-5-8.pdf already exists. Skipping download.
# Downloaded: Apprendre%20la%20programmation%20web%20avec%20Python%20et%20Django%20by%20Gilles%20Degols,%20Pierre%20Alexis,%20Hugues%20Bersini%20(z-lib.org).pdf
# F006116.pdf already exists. Skipping download.
# table-des-matieres.pdf already exists. Skipping download.
# Downloaded: livre.pdf
# Downloaded: php-support.pdf
# Corrupted PDF detected: ../data\php-support.pdf, Error: EOF marker not found
# Deleting corrupted PDF: ../data\php-support.pdf
# back-end-4.pdf already exists. Skipping download.
# cours4-Xquery.pdf already exists. Skipping download.
# Searching for: filetype:pdf Cours SQL sous-requêtes lang:fr
# Error extracting PDFs for query filetype:pdf Cours SQL sous-requêtes lang:fr: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3Dfiletype%253Apdf%2BCours%2BSQL%2Bsous-requ%25C3%25AAtes%2Blang%253Afr%26num%3D102%26hl%3Dfr%26start%3D0%26safe%3Dactive&hl=fr&q=EgRpmtp5GObj8LoGIjCU_RlUK5C-s668oewY_TIFcxdV5ZchEBLgjO4eJM1c0S1jV-4pPy_9QbeOsrx553YyAXJaAUM
# Found 0 PDFs for query: filetype:pdf Cours SQL sous-requêtes lang:fr
# Filtered to 0 relevant PDFs for query: filetype:pdf Cours SQL sous-requêtes lang:fr
# Searching for: filetype:pdf Concepts avancés des bases de données SQL lang:fr
# Error extracting PDFs for query filetype:pdf Concepts avancés des bases de données SQL lang:fr: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3Dfiletype%253Apdf%2BConcepts%2Bavanc%25C3%25A9s%2Bdes%2Bbases%2Bde%2Bdonn%25C3%25A9es%2BSQL%2Blang%253Afr%26num%3D102%26hl%3Dfr%26start%3D0%26safe%3Dactive&hl=fr&q=EgRpmtp5GOfj8LoGIjDCyvuvUB0x4UAvEnA8B-s3NVjm8nxubl4QtIPtC-xoNJV11B9PJXy98fW6scm4Dh0yAXJaAUM
# Found 0 PDFs for query: filetype:pdf Concepts avancés des bases de données SQL lang:fr
# Filtered to 0 relevant PDFs for query: filetype:pdf Concepts avancés des bases de données SQL lang:fr

# %%
import requests
from bs4 import BeautifulSoup
import os
from PyPDF2 import PdfReader

def google_search(query, num_results=100):
    """Perform a Google search and return result links."""
    headers = {"User-Agent": "Mozilla/5.0"}
    search_url = f"https://www.google.com/search?q={query}&num={num_results}"
    response = requests.get(search_url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")
    links = [a['href'] for a in soup.select('a') if 'url?q=' in a['href']]
    return [link.split('&')[0].replace('/url?q=', '') for link in links]

def download_pdf(url, download_dir="../pdfsv"):
    """Download PDF from URL."""
    if not os.path.exists(download_dir):
        os.makedirs(download_dir)
    try:
        response = requests.get(url, stream=True)
        if response.headers.get('content-type') == 'application/pdf':
            filename = os.path.join(download_dir, url.split("/")[-1])
            with open(filename, "wb") as f:
                f.write(response.content)
            return filename
    except Exception as e:
        print(f"Failed to download {url}: {e}")
    return None

def validate_pdf(pdf_path):
    """Validate content of PDF to check if it's SQL-focused."""
    try:
        reader = PdfReader(pdf_path)
        text = " ".join(page.extract_text() for page in reader.pages[:5])
        return "SQL" in text and "SGBD" in text
    except Exception as e:
        print(f"Error reading {pdf_path}: {e}")
    return False

def main():
    query = "filetype:pdf cours SQL en français -webdev -php -oracle -jdbc -java"
    links = google_search(query)
    for link in links:
        if link.endswith(".pdf"):
            pdf_path = download_pdf(link)
            if pdf_path and validate_pdf(pdf_path):
                print(f"Validated and saved: {pdf_path}")
            else:
                print(f"Skipped: {link}")

if __name__ == "__main__":
    main()
# Out:
# Validated and saved: ../pdfsv\Fiche%2520-%2520SQL.pdf
# Skipped: https://www-igm.univ-mlv.fr/~cherrier/download/BD1/cours/SQL-syntaxe.pdf
# Skipped: https://www.i3s.unice.fr/~edemaria/cours/c3.pdf
# Skipped: https://repository.root-me.org/Programmation/SQL/FR%2520-%2520Les%2520bases%2520fondamentales%2520du%2520langage%2520Transact%2520SQL.pdf
# Skipped: http://sql.bdpedia.fr/files/slvues.pdf
# Skipped: https://ressources.unisciel.fr/sillages/informatique/bdd/tpsql_corrige.pdf
# Skipped: http://pascal.delahaye1.free.fr/cpge/informatique/cours/cours11.pdf
# Skipped: https://www.montefiore.uliege.be/services/verif/cours/bd/repet2014/tp6.pdf
# Skipped: http://alexandre.patin.free.fr/fichiers/doc-sql.pdf
# Validated and saved: ../pdfsv\cours-BD2012-cours4Et5.pdf
# Skipped: http://sql.bdpedia.fr/files/sltriggers.pdf
# Skipped: http://www.rzo.free.fr/docs_BD2A/memo_sql.pdf
# Skipped: http://pascal.delahaye1.free.fr/cpge/informatique/td/td13.pdf
# Validated and saved: ../pdfsv\Chap_10_L_acces_aux_donnees.pdf
# Skipped: http://web.univ-ubs.fr/lmba/lardjane/sasl3/c8.pdf
# Validated and saved: ../pdfsv\Cours%2520-%2520Q4.pdf
# Skipped: https://static.fnac-static.com/multimedia/editorial/pdf/9782409027529.pdf
# Skipped: https://repository.root-me.org/Programmation/SQL/FR%2520-%2520D%25C3%25A9buter%2520avec%2520SQL.pdf
# Validated and saved: ../pdfsv\TP3-4.pdf
# Validated and saved: ../pdfsv\cours1-notes.pdf
# Skipped: https://uclouvain.be/cours-2024-minfo1301.pdf
# Validated and saved: ../pdfsv\tp6_sol.pdf
# Validated and saved: ../pdfsv\3i009cours2algebre.pdf
# Skipped: https://www.dawan.fr/formations/bases-de-donnees/ms-sql-server/sql-server-2014--administrer-une-base-de-donnees-%2528cours-ms20462-examen-70-462%2529.pdf
# Skipped: https://cours.ebsi.umontreal.ca/sci6306/docs/sci6306_documentation.pdf
# Skipped: http://fsjes.usmba.ac.ma/cours/alami/si-bd.pdf
# Skipped: http://mapage.noos.fr/ddel/tutoriel/Access_SQL.pdf
# Skipped: https://www.cri.ensmp.fr/~coelho/cours/si/db-sql-adv-8.pdf
pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)')))
# Skipped: https://www.univ-lehavre.fr/wp-content/uploads/2018/11/402-1_informatique.pdf
# Validated and saved: ../pdfsv\S5_Out1.pdf
# Skipped: https://odf.u-paris.fr/plugins/odf-web/uparis/_content/course-bases-de-donnees/Bases%2520de%2520donn%25C3%25A9es.pdf
# Skipped: https://perso.isima.fr/~jofontan/BI/TP2/02_TP2_3_BI_ZZ3_F3_20230103.pdf
# Skipped: http://ekladata.com/u0P-Kd-jm5IUc0KwQ1yA95WgsSc.pdf
# Skipped: https://hal.univ-brest.fr/hal-01167366v1/file/Un-exemple-de-dispositif-constructiviste-en-Licence-2-Informatique-Lily-Blanleuil.pdf

# %%
import requests
from bs4 import BeautifulSoup
import os
from PyPDF2 import PdfReader

download_dir = "../pdfs"

def google_search(query, num_results=100):
    """Perform a Google search and return result links."""
    headers = {"User-Agent": "Mozilla/5.0"}
    search_url = f"https://www.google.com/search?q={query}&num={num_results}"
    response = requests.get(search_url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")
    links = [a['href'] for a in soup.select('a') if 'url?q=' in a['href']]
    return [link.split('&')[0].replace('/url?q=', '') for link in links]

def download_pdf(url):
    """Download PDF from URL."""
    if not os.path.exists(download_dir):
        os.makedirs(download_dir)
    try:
        response = requests.get(url, stream=True)
        if response.headers.get('content-type') == 'application/pdf':
            filename = os.path.join(download_dir, url.split("/")[-1])
            with open(filename, "wb") as f:
                f.write(response.content)
            return filename
    except Exception as e:
        print(f"Failed to download {url}: {e}")
    return None

def validate_pdf(pdf_path):
    """Validate content of PDF to check if it's SQL-focused."""
    try:
        reader = PdfReader(pdf_path)
        text = " ".join(page.extract_text() for page in reader.pages[:5])
        return "SQL" in text and "SGBD" in text
    except Exception as e:
        print(f"Error reading {pdf_path}: {e}")
    return False

def main():
    # Queries targeting pure SQL courses in French
    queries = [
        "filetype:pdf cours SQL en français -webdev -php -java -html",
        "filetype:pdf introduction au langage SQL -webdev -php -java",
        "filetype:pdf apprentissage SQL bases de données en français -webdev -php",
        "filetype:pdf cours SQL norme SQL2 ou SQL3 en français -java -php",
        "filetype:pdf tutoriel SQL SGBD relationnel en français -php -java",
    ]
    for query in queries:
        print(f"Searching for: {query}")
        links = google_search(query)
        for link in links:
            if link.endswith(".pdf"):
                pdf_path = download_pdf(link)
                if pdf_path and validate_pdf(pdf_path):
                    print(f"Validated and saved: {pdf_path}")
                else:
                    print(f"Skipped: {link}")

if __name__ == "__main__":
    main()
# Out:
# Searching for: filetype:pdf cours SQL en français -webdev -php -java -html
# Searching for: filetype:pdf introduction au langage SQL -webdev -php -java
# Searching for: filetype:pdf apprentissage SQL bases de données en français -webdev -php
# Searching for: filetype:pdf cours SQL norme SQL2 ou SQL3 en français -java -php
# Searching for: filetype:pdf tutoriel SQL SGBD relationnel en français -php -java
